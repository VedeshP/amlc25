# %%
import numpy as np
import pandas as pd

# %%
# Define the SMAPE metric function
def smape(y_true, y_pred):
    numerator = np.abs(y_pred - y_true)
    denominator = (np.abs(y_true) + np.abs(y_pred)) / 2
    ratio = np.where(denominator == 0, 0, numerator / denominator)
    return np.mean(ratio) * 100

# %%
train_out = pd.read_csv('train_out.csv')

# %%
train_out.head()
# Out:
#    sample_id      price
# 0          0  20.171875
# 1          4   1.516602
# 2          6   6.347656
# 3         11  21.234375
# 4         12   5.351562

# %%
train = pd.read_csv('train.csv')

# %%
train.head()
# Out:
#    sample_id                                    catalog_content  \
# 0      33127  Item Name: La Victoria Green Taco Sauce Mild, ...
# 1     198967  Item Name: Salerno Cookies, The Original Butte...
# 2     261251  Item Name: Bear Creek Hearty Soup Bowl, Creamy...
# 3      55858  Item Name: Judee’s Blue Cheese Powder 11.25 oz...
# 4     292686  Item Name: kedem Sherry Cooking Wine, 12.7 Oun...
#
#                                           image_link  price
# 0  https://m.media-amazon.com/images/I/51mo8htwTH...   4.89
# 1  https://m.media-amazon.com/images/I/71YtriIHAA...  13.12
# 2  https://m.media-amazon.com/images/I/51+PFEe-w-...   1.97
# 3  https://m.media-amazon.com/images/I/41mu0HAToD...  30.34
# 4  https://m.media-amazon.com/images/I/41sA037+Qv...  66.49

# %%
merged = pd.merge(train, train_out, on='sample_id')

# %%
train.head()
# Out:
#    sample_id                                    catalog_content  \
# 0      33127  Item Name: La Victoria Green Taco Sauce Mild, ...
# 1     198967  Item Name: Salerno Cookies, The Original Butte...
# 2     261251  Item Name: Bear Creek Hearty Soup Bowl, Creamy...
# 3      55858  Item Name: Judee’s Blue Cheese Powder 11.25 oz...
# 4     292686  Item Name: kedem Sherry Cooking Wine, 12.7 Oun...
#
#                                           image_link  price
# 0  https://m.media-amazon.com/images/I/51mo8htwTH...   4.89
# 1  https://m.media-amazon.com/images/I/71YtriIHAA...  13.12
# 2  https://m.media-amazon.com/images/I/51+PFEe-w-...   1.97
# 3  https://m.media-amazon.com/images/I/41mu0HAToD...  30.34
# 4  https://m.media-amazon.com/images/I/41sA037+Qv...  66.49

# %%
merged.head()
# Out:
#    sample_id                                    catalog_content  \
# 0      33127  Item Name: La Victoria Green Taco Sauce Mild, ...
# 1     198967  Item Name: Salerno Cookies, The Original Butte...
# 2     261251  Item Name: Bear Creek Hearty Soup Bowl, Creamy...
# 3      55858  Item Name: Judee’s Blue Cheese Powder 11.25 oz...
# 4     292686  Item Name: kedem Sherry Cooking Wine, 12.7 Oun...
#
#                                           image_link  price_x    price_y
# 0  https://m.media-amazon.com/images/I/51mo8htwTH...     4.89   6.667969
# 1  https://m.media-amazon.com/images/I/71YtriIHAA...    13.12  16.828125
# 2  https://m.media-amazon.com/images/I/51+PFEe-w-...     1.97   4.816406
# 3  https://m.media-amazon.com/images/I/41mu0HAToD...    30.34  15.492188
# 4  https://m.media-amazon.com/images/I/41sA037+Qv...    66.49  24.843750

# %%
y_true = merged['price_x']
y_pred = merged['price_y']

# %%
smape_score = smape(y_true, y_pred)
smape_score
# Out:
# np.float64(36.531929342714584)

# %%
merged.shape
# Out:
# (74972, 5)

# %%
y_pred_test = pd.read_csv('test_out_final.csv')
df_test = pd.read_csv('test.csv')

# %%
merged = pd.merge(df_test, y_pred_test, on='sample_id', how='left')

# %%
merged.head()
# Out:
#    sample_id                                    catalog_content  \
# 0     100179  Item Name: Rani 14-Spice Eshamaya's Mango Chut...
# 1     245611  Item Name: Natural MILK TEA Flavoring extract ...
# 2     146263  Item Name: Honey Filled Hard Candy - Bulk Pack...
# 3      95658  Item Name: Vlasic Snack'mm's Kosher Dill 16 Oz...
# 4      36806  Item Name: McCormick Culinary Vanilla Extract,...
#
#                                           image_link      price
# 0  https://m.media-amazon.com/images/I/71hoAn78AW...  14.921875
# 1  https://m.media-amazon.com/images/I/61ex8NHCIj...  14.101562
# 2  https://m.media-amazon.com/images/I/61KCM61J8e...   9.921875
# 3  https://m.media-amazon.com/images/I/51Ex6uOH7y...   5.136719
# 4  https://m.media-amazon.com/images/I/71QYlrOMoS...  20.250000

# %%
merged.isnull().sum()
merged['price'].fillna(merged['price'].mean(), inplace=True)
# Out:
# C:\Users\vedes\AppData\Local\Temp\ipykernel_34632\2873361029.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged['price'].fillna(merged['price'].mean(), inplace=True)

# %%
final_merge = merged[['sample_id', 'price']]
final_merge.to_csv('submission_only_img.csv', index=False)
